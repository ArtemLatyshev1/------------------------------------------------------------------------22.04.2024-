# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemLatyshev1/------------------------------------------------------------------------22.04.2024-/blob/main/Parsing_avito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

# %%
r = requests.get('https://www.avito.ru/barnaul/kvartiry/prodam-ASgBAgICAUSSA8YQ?context=H4sIAAAAAAAA_0q0MrSqLraysFJKK8rPDUhMT1WyLrYyNLNSKk5NLErOcMsvyg3PTElPLVGyrgUEAAD__xf8iH4tAAAA', headers=headers)

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
name_title_list = []
address_title_list = []
price_title_list = []

# %%
trade_list = soup.find_all('div', {'class': 'items-items-kAJAg'})
for i in trade_list:
  list1 = i.find_all('div', {'class': 'geo-root-zPwRk'})
  print(list1)
  #for j in list1:
    #list1_1 = j.find('a', {'data-marker': 'item-title'})
    #print(list1_1)
# Out:
# [<div class="geo-root-zPwRk"><p class="styles-module-root-YczkZ styles-module-size_s-xb_uK styles-module-size_s-_z7mI stylesMarningNormal-module-root-S7NIr stylesMarningNormal-module-paragraph-s-Yhr2e"><span class="" title=""><a class="styles-module-root-iSkj3 styles-module-root_noVisited-qJP5D styles-module-root_preset_black-PbPLe" data-marker="street_link" href="/barnaul/kvartiry/prodam/vtorichka/street/ulitsa_1905_goda/21474-ASgBAgECA0SSA8YQ5geMUujIE8TPAgFF3AcSInVsaXRzYV8xOTA1X2dvZGEi?context=" target="_blank">ул. 1905 года</a>,<!-- --> <a class="styles-module-root-iSkj3 styles-module-root_noVisited-qJP5D styles-module-root_preset_black-PbPLe" data-marker="house_link" href="/barnaul/kvartiry/prodam/vtorichka/house/ul._1905_goda_25/130793-ASgBAgECA0SSA8YQ5geMUubIE9L7DwFF3AcSInVsLl8xOTA1X2dvZGFfMjUi?context=" target="_blank"> 25</a></span></p><p class="styles-module-root-YczkZ styles-module-size_s-xb_uK styles-module-size_s_compensated-QmHFs styles-module-size_s-_z7mI styles-module-
# ...

# %%
# РАБОТАЕТ, ПОИСК ПО НАЗВАНИЮ
trade_list = soup.find_all('div', {'class': 'items-items-kAJAg'})
for i in trade_list:
  list1 = i.find_all('div', {'class': 'iva-item-title-py3i_'})
  for j in list1:
    list1_1 = j.find('a', {'data-marker': 'item-title'})
    items = list1_1.get('title')
    name_title_list.append(items)
    #print(items)

# %%
print(name_title_list)
# Out:
# ['3-к. квартира, 86\xa0м², 9/12\xa0эт. в Барнауле', 'Квартира-студия, 32\xa0м², 8/16\xa0эт. в Барнауле', '1-к. квартира, 47\xa0м², 3/6\xa0эт. в Барнауле', '1-к. квартира, 53,6\xa0м², 5/9\xa0эт. в Барнауле', '2-к. квартира, 48,3\xa0м², 19/25\xa0эт. в Барнауле', '1-к. квартира, 38,7\xa0м², 10/10\xa0эт. в Барнауле', '3-к. квартира, 80,7\xa0м², 8/16\xa0эт. в Барнауле', 'Своб. планировка, 31,4\xa0м², 2/22\xa0эт. в Барнауле', '1-к. квартира, 43\xa0м², 10/17\xa0эт. в Барнауле', '2-к. квартира, 38\xa0м², 6/10\xa0эт. в Барнауле', '1-к. квартира, 51\xa0м², 16/16\xa0эт. в Барнауле', '3-к. квартира, 91,9\xa0м², 22/24\xa0эт. в Барнауле', 'Квартира-студия, 22,7\xa0м², 6/10\xa0эт. в Барнауле', '2-к. квартира, 53\xa0м², 5/9\xa0эт. в Барнауле', '4-к. квартира, 103,1\xa0м², 1/6\xa0эт. в Барнауле', '2-к. квартира, 70\xa0м², 12/12\xa0эт. в Барнауле', '2-к. квартира, 69,4\xa0м², 8/9\xa0эт. в Барнауле', '1-к. квартира, 32,5\xa0м², 6/12\xa0эт. в Барнауле', '4-к. квартира, 81,4\xa0м², 6/9\xa0эт. в Барнауле'
# ...
